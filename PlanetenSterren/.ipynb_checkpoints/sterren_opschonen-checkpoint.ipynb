# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
tab = pd.read_csv('SterrenCoordinatenVolledig.csv',
                  sep = ',',
                  dtype = {'pl_name' : 'string',
                           'hostname' : 'string',
                           'ra' : 'float',
                           'dec' : 'float',
                           'sy_dist' : 'float',
                           'sy_snum' : 'int',
                           'sy_pnum' : 'int',
                           'st_spectype' : 'string',
                           'st_teff' : 'float',
                           'st_rad' : 'float',
                           'st_mass' : 'float',
                           'rastr' : 'string',
                           'decstr' : 'string'
                          },
                 header = 19)

# %%
tab.drop(['rastr', 'decstr'], axis=1, inplace=True)
tab.dropna(inplace=True)
tab.drop_duplicates(subset=['hostname'], inplace=True)

tab.rename(columns={'pl_name' : 'planet_name',
                    'hostname' : 'starname',
                    'ra' : 'right_ascencion',
                    'dec' : 'declination',
                    'sy_dist' : 'distance',
                    'sy_snum' : 'number_stars',
                    'sy_pnum' : 'number_planets',
                    'st_spectype' : 'spectral_type',
                    'st_teff' : 'star_temp',
                    'st_rad' : 'star_radius',
                    'st_mass' : 'star_mass'},
           inplace=True)

# %%
tab['alpha'] = tab['right_ascencion'].apply(math.radians)
tab['delta'] = tab['declination'].apply(math.radians)

# %%
tab['X'] = tab['delta'].apply(math.cos) * tab['alpha'].apply(math.cos) * tab['distance']
tab['Y'] = tab['delta'].apply(math.cos) * tab['alpha'].apply(math.sin) * tab['distance']
tab['Z'] = tab['delta'].apply(math.sin) * tab['distance']

# %%
tab.to_csv('sterren_zonder_na.csv')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(tab.X, tab.Y, tab.Z)
# Out:
# C:\Users\fgorr\AppData\Local\Temp/ipykernel_3504/1809708571.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
plt.scatter(tab.X, tab.Y)
